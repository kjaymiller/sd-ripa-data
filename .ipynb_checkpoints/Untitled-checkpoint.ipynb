# %%
import pandas
import eland
import os
from elasticsearch import Elasticsearch

# %%
df = pandas.read_csv('ripa_stops_datasd.csv')
# Out:
# /Users/kjaymiller/.pyenv/versions/3.9.1/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (12,16) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df.head()
# Out:
#    stop_id        ori agency  exp_years   date_stop time_stop  stopduration  \
# 0     2443  CA0371100     SD         10  2018-07-01  00:01:37            30
# 1     2444  CA0371100     SD         18  2018-07-01  00:03:34            10
# 2     2447  CA0371100     SD          1  2018-07-01  00:05:43            15
# 3     2447  CA0371100     SD          1  2018-07-01  00:05:43            15
# 4     2448  CA0371100     SD          3  2018-07-01  00:19:06             5
#
#    stop_in_response_to_cfs  officer_assignment_key  \
# 0                        0                       1
# 1                        0                       1
# 2                        1                      10
# 3                        1                      10
# 4                        0                       1
#
#                                       assignment  ...          beat_name  pid  \
# 0  Patrol, traffic enforcement, field operations  ...  Pacific Beach 122    1
# ...

# %%
# Problem Beat name Different than Beat
pandas.unique(df['beat_name'])
# Out:
# array(['Pacific Beach 122', 'Mission Beach 121', 'El Cerrito 822',
#        'Ocean Beach 614', 'University City 115', 'Lincoln Park 446',
#        'Colina Del Sol 826', 'Balboa Park 531', 'La Jolla 124',
#        'Gaslamp 523', 'Carmel Mountain 232', 'Castle 834',
#        'Mountain View 441', 'Otay Mesa 713', 'North Clairemont 114',
#        'Lake Murray 324', 'Otay Mesa West 723', 'Horton Plaza 525',
#        'Nestor 722', 'Marina 522', 'Fairmount Village 833', 'Midtown 628',
#        'Sorrento Valley 931', 'Mission Valley West 623',
#        'Linda Vista 621', 'Golden Hill 517', 'Talmadge 824',
#        'Corridor 838', 'Barrio Logan 511', 'Clairemont Mesa East 111',
#        'Carmel Valley 934', 'Logan Heights 512', 'Core-Columbia 524',
#        'Hillcrest 627', 'Mira Mesa 242', 'North Park 813',
#        'Cherokee Point 839', 'Kearney Mesa 313', 'Normal Heights 811',
#        'Palm City 724', 'San Ysidro 712', 'Midway District 611',
# ...

# %%
# Solution 1
df[['beat_name', 'beat']] = df['beat_name'].str.rsplit(' ', 1, expand=True)

# %%
df.head()
# Out:
#    stop_id        ori agency  exp_years   date_stop time_stop  stopduration  \
# 0     2443  CA0371100     SD         10  2018-07-01  00:01:37            30
# 1     2444  CA0371100     SD         18  2018-07-01  00:03:34            10
# 2     2447  CA0371100     SD          1  2018-07-01  00:05:43            15
# 3     2447  CA0371100     SD          1  2018-07-01  00:05:43            15
# 4     2448  CA0371100     SD          3  2018-07-01  00:19:06             5
#
#    stop_in_response_to_cfs  officer_assignment_key  \
# 0                        0                       1
# 1                        0                       1
# 2                        1                      10
# 3                        1                      10
# 4                        0                       1
#
#                                       assignment  ...      beat_name  pid  \
# 0  Patrol, traffic enforcement, field operations  ...  Pacific Beach    1
# ...

# %%
# Upload to Elastic Cloud

client = Elasticsearch(
    cloud_id=os.environ.get('CLOUD_ID'),
    auth=(os.environ.get('ES_CLIENT_USERNAME'),
         os.environ.get('ES_CLIENT_PASSWORD')
         )
)

# %%
ed = eland.pandas_to_eland(
                df,
                es_client=client,
                es_dest_index="sd-ripa-basic-stop",
                es_if_exists="replace",
                es_refresh=True,
            )
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# ~/.pyenv/versions/3.9.1/lib/python3.9/site-packages/urllib3/connection.py in _new_conn(self)
#     168         try:
# --> 169             conn = connection.create_connection(
#     170                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# ~/.pyenv/versions/3.9.1/lib/python3.9/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      95     if err is not None:
# ---> 96         raise err
#      97
#
# ~/.pyenv/versions/3.9.1/lib/python3.9/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      85                 sock.bind(source_address)
# ---> 86             sock.connect(sa)
#      87             return sock
#
# ConnectionRefusedError: [Errno 61] Connection refused
#
# ...
